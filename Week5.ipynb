# %% [markdown]
# <a href="https://colab.research.google.com/github/lilipolinema/PCVK_Genap_2021/blob/master/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Nama: Lili Nur Indah Sari**
#
# **Kelas: TI-3F**
#
# **NIM: 1841720037**

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import math

# %% [markdown]
# 1. Buat Gamma Correction sesuai dengan petunjuk berikut

# %%
print('Gamma Correction on Citra')
print('--------------------------')
try:
  gamma = int(input('Masukkan nilai Gamma :'))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/PCVK/Images/female.tiff')
gamma_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for z in range(original.shape[2]):
      gamma_image[y,x,z] = np.clip(255 * pow(original[y,x,z]/255,(1/gamma)),0,255)

final_frame = cv.hconcat((original, gamma_image))
cv2_imshow(final_frame)
# Out:
# Gamma Correction on Citra
# --------------------------
# Masukkan nilai Gamma :3
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FBA7E9BC4D0>

# %% [markdown]
# 3. Buat modul Average Denoising

# %%
from matplotlib import pyplot as plt

print(' Gamma Correction pada citra ')
print('----------------------------------')
try:
  db = int(input('Masukkan nilai db: '))
except ValueError:
  print('Error, not a number')

img2 = cv.imread('/content/drive/MyDrive/PCVK/Images/noises/1.jpg')

# denoising of image saving it into dst image 
dst = cv.fastNlMeansDenoisingColored(img2, None, 10, db, 7, 15) 

# Plotting of source and destination image 
final_frame = cv.hconcat((img2, dst))
cv2_imshow(final_frame)
# Out:
#  Gamma Correction pada citra
# ----------------------------------
# Masukkan nilai db: 5
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FBA77DEA610>

# %%
from matplotlib import pyplot as plt

print(' Gamma Correction pada citra ')
print('----------------------------------')
try:
  db = int(input('Masukkan nilai db: '))
except ValueError:
  print('Error, not a number')

img2 = cv.imread('/content/drive/MyDrive/PCVK/Images/noises/1.jpg')

# denoising of image saving it into dst image 
dst = cv.fastNlMeansDenoisingColored(img2, None, 10, db, 7, 15) 

# Plotting of source and destination image 
final_frame = cv.hconcat((img2, dst))
cv2_imshow(final_frame)
# Out:
#  Gamma Correction pada citra
# ----------------------------------
# Masukkan nilai db: 50
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FBA77DEA790>

# %%
from matplotlib import pyplot as plt

print(' Gamma Correction pada citra ')
print('----------------------------------')
try:
  db = int(input('Masukkan nilai db: '))
except ValueError:
  print('Error, not a number')

img2 = cv.imread('/content/drive/MyDrive/PCVK/Images/noises/1.jpg')

# denoising of image saving it into dst image 
dst = cv.fastNlMeansDenoisingColored(img2, None, 10, db, 7, 15) 

# Plotting of source and destination image 
final_frame = cv.hconcat((img2, dst))
cv2_imshow(final_frame)
# Out:
#  Gamma Correction pada citra
# ----------------------------------
# Masukkan nilai db: 80
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FBA77DB6AD0>

# %%
from matplotlib import pyplot as plt

print(' Gamma Correction pada citra ')
print('----------------------------------')
try:
  db = int(input('Masukkan nilai db: '))
except ValueError:
  print('Error, not a number')

img2 = cv.imread('/content/drive/MyDrive/PCVK/Images/noises/1.jpg')

# denoising of image saving it into dst image 
dst = cv.fastNlMeansDenoisingColored(img2, None, 10, db, 7, 15) 

# Plotting of source and destination image 
final_frame = cv.hconcat((img2, dst))
cv2_imshow(final_frame)
# Out:
#  Gamma Correction pada citra
# ----------------------------------
# Masukkan nilai db: 100
# <PIL.Image.Image image mode=RGB size=620x256 at 0x7FBA77DB6950>

# %% [markdown]
# 4. Buat image masking untuk image berikut. Image kiri adalah image asli (images/teeth.jpg),
# sedangkan image kanan adalah hasilnya:

# %% [markdown]
# OR

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/Images/teeth.jpg')
mask_or = np.zeros(img.shape, dtype=np.uint8)
mask_or = cv.rectangle(mask_or,pt1=(320,595),pt2=(800,1025),color=(255,255,255),thickness=-1)

result = img | mask_or

mask_or1 = cv.rectangle(mask_or,pt1=(405,5),pt2=(850,455),color=(255,255,255),thickness=-1)

result_or1 = img | mask_or1

final_frame = cv.hconcat((img, result_or1))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=2708x1036 at 0x7FBA77D0A950>

# %% [markdown]
# NOT

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/Images/teeth.jpg')
mask = np.zeros(img.shape, dtype=np.uint8)
mask = cv.circle(mask, (260, 300), 225, (255,255,255), -1)

result = img ^ mask
#result[mask==255]=0

final_frame = cv.hconcat((img, mask, result))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=4062x1036 at 0x7FBA77DB6BD0>

# %% [markdown]
# AND

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/Images/teeth.jpg') 
mask = np.zeros(img.shape, dtype=np.uint8)
mask = cv.rectangle(mask,pt1=(320,595),pt2=(800,1025),color=(255,255,255),thickness=-1)

result = img & mask

mask1 = cv.rectangle(mask,pt1=(405,5),pt2=(850,455),color=(255,255,255),thickness=-1)

result = img & mask1

final_frame = cv.hconcat((img, result))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=2708x1036 at 0x7FBA77D0E190>
