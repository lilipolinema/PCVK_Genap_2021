# %% [markdown]
# <a href="https://colab.research.google.com/github/lilipolinema/PCVK_Genap_2021/blob/master/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Lili Nur Indah Sari
#
# Kelas: TI-3F
#
# NIM: 1841720037

# %% [markdown]
# 1. import folder yang ada di Drive

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# membuka file Google Drive yang sudah ada

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/rubah.jpg')
plt.imshow(img)

# %% [markdown]
# 2. OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red) Tampilkan nilai pixel dan image

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)    #konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# **TUGAS**
#
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?
# 2. Tampilkan image dalam channel Red-Green dan Green-Blue saja!
# 3. Tampilkan image baris ke 20-250, kolom 20-250!
# 4. Tampilkan image baris ke 7-27, semua kolom, channel Red saja!
# 5. Buat 3 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!

# %% [markdown]
# **Jawab:**
#
# 1.

# %%
img12 = img

#tampilkan plot dengan ukuran convas yang lebih besar
fig = plt.figure(figsize=(5,5))     # Ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img12)

# %% [markdown]
# 2.

# %%
img8 = cv.imread('/content/drive/MyDrive/PCVK/rubah.jpg')
img9 = cv.cvtColor(img8,cv.COLOR_BGR2RGB) #to RGB
rg = img9.copy() # make a copy
rg[:,:,2] = 0
plt.imshow(rg)

# %%
gb = img9.copy()
gb[:,:,0] = 0
plt.imshow(gb)

# %% [markdown]
# 3.

# %%
img10 = img9
imgbk = img10[10:100,10:100]
plt.imshow(imgbk)

# %% [markdown]
# 4.

# %%
img15 = img9.copy()
img15[:,:,1] = 0
img15[:,:,2] = 0
img30 = img15[5:30]
plt.imshow(img30)

# %% [markdown]
# 5.

# %%
square = img9
cv.rectangle(square, pt1=(128,20), pt2=(133,50),color=(255,0,0),thickness=2)
cv.rectangle(square, pt1=(270,110), pt2=(300,140),color=(0,255,0),thickness=3)
cv.rectangle(square, pt1=(325,210), pt2=(370,240),color=(0,0,255),thickness=4)
plt.imshow(square)

# %% [markdown]
# 3. Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan citra hasil

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/alpaca.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘magma’

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)

# Simpan file image
#cv.imwriter('/content/drive/MyDrive/PCVK/rubah.jpg',img5)

#tampilkan plot dengan ukuran convas yang lebih besar
fig = plt.figure(figsize=(10,10))     # Ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# 4. Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image dengan tipe data int16.

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
#prhatikankoordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2 yang tertulis pada kode program.

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang tertulis pada kode program.

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah ditentukan.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1,1,2)) # Nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# 5. Setelah semua kode selesai simpan “Week2.ipynb” pada GiHub Anda dengan memilih File kemudian “Save a copy in GitHub”.

# %% [markdown]
# **TUGAS**
#
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# 1. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).
# 2. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!
# 3. Tulis nama file pada file citra dari soal no.2. Gunakan font, ukuran font, dan
# warna font yang sesuai keinginan anda.
# Tunjukkan code program anda pada bapak/ibu dosen

# %% [markdown]
# 1.

# %%
poto = cv.imread('/content/drive/MyDrive/PCVK/poto.jpeg')
img10 = cv.cvtColor(poto,cv.COLOR_BGR2RGB)

cv.rectangle(img10, pt1=(500,420), pt2=(320,580),color=(255,0,0),thickness=2)
cv.circle(img10, center=(400,500), radius=80,color=(0,0,255),thickness=2)

plt.imshow(img10)

# %% [markdown]
# 2.

# %%
female = cv.imread('/content/drive/MyDrive/PCVK/female.jpg')
female = cv.cvtColor(female,cv.COLOR_BGR2RGB)

plt.imshow(female)

# %%
cv.rectangle(female, pt1=(300,750),pt2=(10,1000),color=(255,255,255),thickness=2)
plt.imshow(female)

# %% [markdown]
# 3.

# %%
font = cv.FONT_HERSHEY_TRIPLEX
cv.putText(female,text='Female',org=(100,1200),fontFace=font,fontScale=4,color=(0,0,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(female)

# %% [markdown]
# Pertanyaan
#
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3

# %% [markdown]
# Jawab:
#
# 1. perbedaannya adalah, ketika menggunakan matplotlib itu kita bisa tahu panjang dan lebar dari gambar yang kita tampilkan. dan ketika tidak menggunakan, maka kita tidak tahu panjang dan lebar dari gambar yang kita tampilkan
# 2.int16= ukuran 2 byte, sedangkan int32= berukuran 4 byte. pada black img, type data int32 jumlah pixel lebih banyak dibanding int16. karena black img tipe data32 terlihat lebih hitam daripada black img tipe data16
# 3. digunakan menampilkan gambar
# 4. skimage adalah library yg mendukung img processing application di python.
